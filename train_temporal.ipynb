# %%
from ultralytics import YOLO

if __name__ == '__main__':
    # 1. تحميل المعمارية الخاصة بك (YOLO11 مع CBAM)
    model = YOLO(r'/teamspace/studios/this_studio/ultralytics/ultralytics/cfg/models/11/yolo11-cbam-pose.yaml')
    # ملاحظة: لو بتشتغل محلياً على جهازك الـ Lenovo، عدل المسار ليكون المسار المحلي عندك

    # 2. بدء عملية التدريب مع دمج الأوزان السابقة لتسريع التعلم
    results = model.train(
        data=r'/teamspace/studios/this_studio/ultralytics/KLYVERO_Dataset/data.yaml', # عدل المسار حسب جهازك
        pretrained=r'/teamspace/studios/this_studio/ultralytics/runs/pose/KLYVERO_Engine/yolo11n_body_12kpt-2/weights/best.pt',
        epochs=50,          # نبدأ بـ 50 إطار لنرى استجابة الخسارة الزمنية الجديدة
        imgsz=640,
        batch=16,
        freeze=10,          # تجميد الطبقات الأولى للحفاظ على استخراج المعالم
        project='KLYVERO_Engine',
        name='yolo11n_CBAM_Temporal_Loss'
    )

print("✅ تم بدء تدريب نموذج KLYVERO بنجاح مع Temporal Consistency Loss!")
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.142 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.140 🚀 Python-3.12.11 torch-2.8.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# ...
